# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ccv_run1 = [0.611,0.563,0.709,0.530,0.518,0.561,0.719, 0.551,0.594,0.520,0.685,0.670 ,0.708,0.627,0.560,0.631,
0.736,0.569,0.679,0.650,0.688,0.627,0.659,0.557,0.567,0.595,0.530,0.645,0.413,0.593,0.439,0.733]

# %%
ccv_run3 = [0.962, 0.872, 1.055, 0.874, 0.833, 0.886, 1.223, 0.949, 0.903, 0.853, 1.020, 1.072, 1.113, 1.026, 0.894, 1.000, 
            1.095, 0.926, 1.084, 1.058, 1.016, 1.052, 1.053, 0.880, 0.921, 0.919, 0.864, 0.958, 0.618, 0.927, 0.706, 0.913]

# %%
fig, ax = plt.subplots(figsize=(8,3))
ratio = ccv_run3/np.array(ccv_run1)
ax.plot(range(32),ratio)
ax.axhline(y=np.mean(ratio),color='C1', alpha=0.6, label='mean: {0:0.2f}'.format(np.mean(ratio)))
ax.set_xticks(range(32))
ax.set_xlim(0,31)
ax.set_xlabel('Opdet Id')
ax.set_ylabel('CCV_run3 / CCV_run1')
ax.legend()
fig.savefig('ccv_ratio.pdf')

# %%
np.round(ratio,2)
# Out:
# array([1.57, 1.55, 1.49, 1.65, 1.61, 1.58, 1.7 , 1.72, 1.52, 1.64, 1.49,
#        1.6 , 1.57, 1.64, 1.6 , 1.58, 1.49, 1.63, 1.6 , 1.63, 1.48, 1.68,
#        1.6 , 1.58, 1.62, 1.54, 1.63, 1.49, 1.5 , 1.56, 1.61, 1.25])
